# %% [markdown]
# # Building and using styles in matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

# %% [markdown]
# ## rcParams
#
# rcParams are settings for matplotlib. They're how stylesheets work (the thing when you use `plt.style.use`.
#
# You can find examples of the different styles [here](https://matplotlib.org/2.1.1/gallery/style_sheets/style_sheets_reference.html) and [here](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html).
#
# > **A big long list is:** bmh, classic, dark_background, fivethirtyeight, ggplot, grayscale, seaborn-bright, seaborn-colorblind, seaborn-dark, seaborn-dark-palette, seaborn-darkgrid, seaborn-deep, seaborn-muted, seaborn-notebook, seaborn-paper, seaborn-pastel, seaborn-poster, seaborn-talk, seaborn-ticks, seaborn-white, seaborn-whitegrid
#
# If you think one of them is cool, you can find its rcparams styles by checking out its mplstyle file in [in this directory](https://github.com/matplotlib/matplotlib/tree/master/lib/matplotlib/mpl-data/stylelib).

# %% [markdown]
# ### FiveThirtyEight
#
# This is the same as `plt.style.use('fivethirtyeight')`. You can find the file it's based on [right here](https://github.com/matplotlib/matplotlib/blob/master/lib/matplotlib/mpl-data/stylelib/fivethirtyeight.mplstyle).

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#   'lines.linewidth': 4,
#   'lines.solid_capstyle': 'butt',
#   'legend.fancybox': True,
#   'axes.prop_cycle': cycler('color', ['#008fd5', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b', '#810f7c']),
#   'axes.facecolor': '#f0f0f0',
#   'axes.labelsize': 'large',
#   'axes.axisbelow': True,
#   'axes.grid': True,
#   'axes.edgecolor': '#f0f0f0',
#   'axes.linewidth': 3.0,
#   'axes.titlesize': 'x-large',
#   'patch.edgecolor': '#f0f0f0',
#   'patch.linewidth': 0.5,
#   'svg.fonttype': 'path',
#   'grid.linestyle': '-',
#   'grid.linewidth': 1.0,
#   'grid.color': '#cbcbcb',
#   'xtick.major.size': 0,
#   'xtick.minor.size': 0,
#   'ytick.major.size': 0,
#   'ytick.minor.size': 0,
#   'font.size': 14.0,
#   'savefig.edgecolor': '#f0f0f0',
#   'savefig.facecolor': '#f0f0f0',
#   'figure.subplot.left': 0.08,
#   'figure.subplot.right': 0.95,
#   'figure.subplot.bottom': 0.07,
#   'figure.facecolor': '#f0f0f0',
# })

# %% [markdown]
# ### ggplot
#
# This is the same as `plt.style.use('ggplot')`. You can find the file it's based on [here](https://github.com/matplotlib/matplotlib/blob/master/lib/matplotlib/mpl-data/stylelib/ggplot.mplstyle).

# %%
# plt.rcdefaults()
# plt.rcParams.update({
#   'patch.linewidth': 0.5,
#   'patch.facecolor': '#348ABD',
#   'patch.edgecolor': '#EEEEEE',
#   'patch.antialiased': True,
#   'font.size': 10.0,
#   'axes.facecolor': '#E5E5E5',
#   'axes.edgecolor': 'white',
#   'axes.linewidth': '1',
#   'axes.grid': True,
#   'axes.titlesize': 'x-large',
#   'axes.labelsize': 'large',
#   'axes.labelcolor': '#555555',
#   'axes.axisbelow': True,
#   'axes.prop_cycle': cycler('color', ['#E24A33', '#348ABD', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8']),
#   'xtick.color': '#555555',
#   'xtick.direction': 'out',
#   'ytick.color': '#555555',
#   'ytick.direction': 'out',
#   'grid.color': 'white',
#   'grid.linestyle': '-',
#   'figure.facecolor': 'white'
# })

# %% [markdown]
# ### Yours!
#
# My abbreviated list of options to update can be found [here as a gist](https://gist.github.com/jsoma/8e453751dac9961afdef87c81ea4d5a4).
#
# Make sure you put **commas at the end of your lines.**

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
})

# %% [markdown]
# # Grouped bar graph (2 colors)

# %%
df = pd.read_csv("15-homework/gender.csv")
df.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>male</th>
#       <th>female</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Texas</td>
#       <td>30</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>New Mexico</td>
#       <td>45</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Colorado</td>
#       <td>32</td>
#       <td>44</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ax = df.plot(x='state', kind='barh', figsize=(10, 4))

# CUSTOMIZATION CODE GOES UNDER HERE
plt.rcdefaults()
plt.rcParams.update({
  'figure.facecolor': 'd5e2e9',
  'figure.edgecolor': 'none',
  'figure.frameon': False,
  
  'font.family': 'sans-serif',
  'font.sans-serif': ['BentonSansCond', 'sans-serif'],
  'font.stretch': 'normal',
  'font.weight': 400,
  
  'lines.linewidth': 3,
  'lines.dash_joinstyle': 'miter',
  'lines.solid_joinstyle': 'miter',
  'lines.dash_capstyle': 'butt',
  'lines.solid_capstyle': 'butt',
  
  'text.hinting': 'either',
  'axes.facecolor': 'None',
  'axes.edgecolor': 'FFFFFF',
  'axes.grid': True,
  'axes.grid.axis': 'y',
  'axes.axisbelow': True,
  'axes.spines.left': True,
  'axes.spines.top': False,
  'axes.spines.bottom': False,
  'axes.spines.right': False,
  'axes.titleweight': 700,
  'axes.prop_cycle': cycler('color', ['#024A61', '#72CEF3', '#6593a5',
                                      '#049ed7', '#ababad', '#7e67b7', '#568b2b']),
  
  'xtick.top': False,
  'xtick.bottom': False,
  'xtick.labeltop': True,
  'xtick.labelbottom': False,
  'xtick.minor.pad': 1,
  'xtick.major.pad': 1,
  
  'ytick.left': False,
  'ytick.right': False,
  'ytick.alignment': 'center_baseline',
  
  'grid.color': '#FFFFFF',
  'grid.alpha': 0.8,
  'grid.linewidth': 0.5,

  'legend.frameon': False,
  'legend.loc': 'lower left',
  'legend.borderpad': 0.,
  'legend.labelspacing': 2.,
  'legend.columnspacing': 2,
  'legend.handletextpad': 0.8,

  'savefig.facecolor': 'd5e2e9',
  'savefig.transparent': False,
  'savefig.frameon': False
})

# Somehow setting that in the defaults doesn't work?
ax.grid(axis='y')
plt.legend(bbox_to_anchor=(0., -0.1, 1., 0.), ncol=4,
           mode="expand")

# then we save it
plt.savefig("15-homework/economist-graph-bar-grouped.pdf")
plt.show()
# Out:
# 'BentonSansCond-Book.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# # Bar graph (Single color)

# %%
df = pd.read_csv("15-homework/countries.csv")
result = df.groupby("continent").life_expectancy.median().sort_values()
result
# Out:
# continent
# Africa        52.1025
# Oceania       67.4955
# Asia          70.4275
# N. America    70.5765
# S. America    70.7660
# Europe        75.5800
# Name: life_expectancy, dtype: float64

# %%
color = plt.rcParams['axes.prop_cycle'].by_key()['color'][0]
ax = result.plot(kind='barh', figsize=(10, 5), color=color)

# CUSTOMIZATION CODE GOES UNDER HERE
ax.grid(axis='y')

# then we save it
plt.savefig("15-homework/economist-graph-bar.pdf")
plt.show()
# Out:
# 'BentonSansCond-Book.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# # Line graph

# %%
df = pd.read_csv("15-homework/visas-by-continent-long.csv")
df = df.groupby(["year", "continent"]).visas.sum().unstack().reset_index()
df.drop(columns='Unknown', inplace=True)
df['year'] = pd.to_datetime(df.year, format="%Y")
df.set_index('year', inplace=True)
percent_df = df.div(df.sum(axis=1), axis='rows') * 100

percent_df.head(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>continent</th>
#       <th>Africa</th>
#       <th>Asia</th>
#       <th>Europe</th>
#       <th>North America</th>
#       <th>Oceania</th>
#       <th>South America</th>
#     </tr>
#     <tr>
#       <th>year</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1997-01-01</th>
#       <td>4.532365</td>
#       <td>40.533368</td>
#       <td>19.424055</td>
#       <td>16.410128</td>
#       <td>0.787181</td>
#       <td>18.312904</td>
#     </tr>
#     <tr>
#       <th>1998-01-01</th>
#       <td>4.905586</td>
#       <td>35.360192</td>
#       <td>18.980460</td>
#       <td>21.200149</td>
#       <td>0.812552</td>
#       <td>18.741061</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ax = percent_df.plot(kind='line', figsize=(10, 5))

# CUSTOMIZATION CODE GOES UNDER HERE
# since we don't reset everything, we just need to update a few things here 
# to get it in line with the Economist
plt.rcParams.update({
  'axes.spines.bottom': True,
  'axes.spines.left': False,
  'axes.edgecolor': '000000',


  'xtick.bottom': True,
  'xtick.labeltop': False,
  'xtick.labelbottom': True,
  'xtick.direction': 'in',
  'xtick.major.size': 4,
  'xtick.minor.size': 3.5,
  'xtick.major.width': 0.5,
  'xtick.minor.width': 0.5,
  'xtick.minor.pad': 3,
  'xtick.major.pad': 3,

})
ax.grid(axis='x')
plt.legend(bbox_to_anchor=(0., 1., 1., 0.), ncol=3,
           mode="expand")
# then we save it
plt.savefig("15-homework/economist-graph-lines.pdf")
plt.show()
# Out:
# 'BentonSansCond-Book.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# # Scatter plot

# %%
df = pd.read_csv("15-homework/countries.csv")
df.head(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>continent</th>
#       <th>gdp_per_capita</th>
#       <th>life_expectancy</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Afghanistan</td>
#       <td>Asia</td>
#       <td>663</td>
#       <td>54.863</td>
#       <td>22856302</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Albania</td>
#       <td>Europe</td>
#       <td>4195</td>
#       <td>74.200</td>
#       <td>3071856</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Don't touch this part of the code!
colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

groups = df.groupby('continent')
for name, group in groups:
    group.plot(kind='scatter', x='gdp_per_capita', y='life_expectancy', color=colors.pop(), label=name, s= 5 + (group.population / 200000), ax=ax, alpha=0.75)
ax.legend_.remove()

# CUSTOMIZATION CODE GOES UNDER HERE

plt.rcParams.update({
  'axes.spines.bottom': True,
  'axes.spines.left': False,
  'axes.edgecolor': '000000',

  'xtick.bottom': True,
  'xtick.labeltop': False,
  'xtick.labelbottom': True,
  'xtick.direction': 'in',
  'xtick.major.size': 4,
  'xtick.minor.size': 3.5,
  'xtick.major.width': 0.5,
  'xtick.minor.width': 0.5,
  'xtick.minor.pad': 3,
  'xtick.major.pad': 3,

})

ax.grid(axis='x')

# then we save it
plt.savefig("15-homework/economist-graph-scatter.pdf")
plt.show()
# Out:
# 'BentonSansCond-Book.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
